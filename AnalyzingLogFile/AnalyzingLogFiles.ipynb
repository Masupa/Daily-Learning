# %% [markdown]
# <a href="https://colab.research.google.com/github/Masupa/Daily-Learning/blob/main/AnalyzingLogFile/AnalyzingLogFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-027ebd52-8e39-467f-aa85-cff2ec7e7b23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-027ebd52-8e39-467f-aa85-cff2ec7e7b23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving new_log to new_log (1)

# %%
import io
import re
import pytz
from datetime import datetime

# %% [markdown]
# **Helper Functions - Regular Expressions**

# %%
def parse_str(string):
  """
  Returns a string delimited by two characters
  Example:
    >>> 'parse_str('[My_string]')
    return value: 'My_string'
  """

  if string is None:
    return '-'

  try:
    return string[1: -1]
  except ValueError:
    return '-'

# %%
def parse_int(string):
  """
  Returns parsed string if no error occured, else 0
  """

  if string is None:
    return 0
  try:
    y = int(string)
    return y
  except ValueError:
    return 0

# %%
def parse_datetime(string):
  """
  Parses datetime with timezone formatted as `[day/month/year:hour:minute:second zone]`
  
  Example:
    `>>> parse_datetime('13/Nov/2015:11:45:42 +0000')`
    return value: datetime.datetime(2015, 11, 3, 11, 45, 4, tzinfo=<UTC>)
  
  Due to problems parsing the timezone (`%z`) with `datetime.strptime`, the
  timezone will be obtained using the `pytz` library.
  """

  try:
    dt = datetime.strptime(string[1:-7], '%d/%b/%Y:%H:%M:%S')
    dt_tz = int(string[-6:-3]) * 60 + int(string[-3:-1])
    return dt.replace(tzinfo=pytz.FixedOffset(dt_tz))

  except ValueError:
    return '-'

# %% [markdown]
# **Load logfile dataset**

# %%
log_data = pd.read_csv(
    io.BytesIO(uploaded['new_log']),
    error_bad_lines=False,
    sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
    engine='python',
    na_values='-',
    header=None,
    usecols=[0, 3, 4, 5, 6, 7, 8],
    names=['Client_IP_Address', 'Time_of_activity', 'Requested_Page', \
           'Status_Code', 'Size_of_Page', 'Referer_Page', 'Client_Device'],
    converters={'Time_of_activity': parse_datetime,
                'Requested_Page': parse_str,
                'Status_Code': parse_int,
                'Size_of_Page': parse_int,
                'Referer_Page': parse_str,
                'Client_Device': parse_str},
                )

# %%
log_data.head()
# Out:
#   Client_IP_Address  ...                                      Client_Device
# 0   109.169.248.247  ...  Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20...
# 1   109.169.248.247  ...  Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20...
# 2       46.72.177.4  ...  Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20...
# 3       46.72.177.4  ...  Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20...
# 4    83.167.113.100  ...  Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20...
#
# [5 rows x 7 columns]

# %% [markdown]
# **Solutions**

# %% [markdown]
# 1. Find 10 people who visited the site frequently, show the information that identify the people and state why you identify these people as frequent visitors.

# %%
# Groupby Client_IP_Address & Client Device and aggregate by count
user_groupby = log_data.groupby(by=['Client_IP_Address', 'Client_Device'])[['Time_of_activity']].count()

# Sort "user_groupby" DataFrame in descending order
top_10_users_sorted = user_groupby.sort_values(by='Time_of_activity', ascending=False).iloc[:10]
top_10_users_sorted.columns = ['Number_of_time_website_accessed']

top_10_users_sorted.reset_index()
# Out:
#   Client_IP_Address  ... Number_of_time_website_accessed
# 0    205.167.170.15  ...                           29516
# 1     79.142.95.122  ...                            3205
# 2    205.167.170.15  ...                            1733
# 3      37.1.206.196  ...                            1428
# 4      91.200.12.22  ...                             551
# 5    213.150.254.81  ...                             434
# 6     84.112.161.41  ...                             414
# 7    205.167.170.15  ...                             413
# 8      84.58.165.21  ...                             381
# 9     52.22.118.215  ...                             367
#
# [10 rows x 3 columns]

# %% [markdown]
# **2. Show at least five sessions and the page views per each session.**

# %%
# Groupby variables of interest
sessions_per_page = log_data.groupby(by=['Client_IP_Address', 'Client_Device', 'Time_of_activity', 'Requested_Page']).count()[['Status_Code']].reset_index()

# Drop "Status_Code" column
sessions_per_page.drop("Status_Code", axis=1, inplace=True)

# %%
sessions_per_page.head(20)
# Out:
#    Client_IP_Address  ...                                     Requested_Page
# 0        1.0.176.215  ...                GET /apache-log/access.log HTTP/1.1
# 1        1.0.176.215  ...                GET /apache-log/access.log HTTP/1.1
# 2        1.0.176.215  ...                GET /apache-log/access.log HTTP/1.1
# 3        1.0.176.215  ...                         GET /wp-login.php HTTP/1.1
# 4        1.0.176.215  ...                GET /apache-log/access.log HTTP/1.1
# 5        1.0.176.215  ...  GET /index.php?option=com_easyblog&view=dashbo...
# 6        1.0.176.241  ...                GET /apache-log/access.log HTTP/1.1
# 7        1.0.176.241  ...                         GET /wp-login.php HTTP/1.1
# 8        1.0.176.241  ...                GET /apache-log/access.log HTTP/1.1
# 9        1.0.176.241  ...  GET /index.php?option=com_easyblog&view=dashbo...
# 10       1.0.178.124  ...                GET /apache-log/access.log HTTP/1.1
# 11       1.0.178.124  ...                         GET /wp-login.php HTTP/1.1
# 12       1.0.178.124  ...                GET /apache-log/access.log HTTP/1.1
# 13       1.0.178.124  ...  GET /index.php?option=com_easyblog&view=dashbo...
# 14        1.0.178.41  ...                GET /apache-log/access.log HTTP/1.1
# 15        1.0.178.41  ...                         GET /wp-login.php HTTP/1.1
# 16        1.0.178.41  ...                         GET /wp-login.php HTTP/1.1
# 17        1.0.178.41  ...                GET /apache-log/access.log HTTP/1.1
# 18        1.0.178.41  ...  GET /index.php?option=com_easyblog&view=dashbo...
# 19         1.0.178.5  ...                GET /apache-log/access.log HTTP/1.1
#
# [20 rows x 4 columns]

# %% [markdown]
# **3. Show five frequent pages which the users visit before visiting this particular web site.**

# %%
# Drop rows with NaN values
log_data.dropna(how='any', inplace=True)

# Adding "www." to "Referer_Page" urls without it
full_url = log_data[log_data['Referer_Page'].str.contains('www.') == False]['Referer_Page'].str.replace('http://', 'http://www.')

# %%
def make_full_url(url):
  """
  url: Url representing the Referer_Page
  
  Example:
    url: "http://google.com"
    return: "http://www.google.com
  """

  if url.startswith('http://www'):
    pass
  else:
    return url.replace('http://', 'http://www.')

# %%
# Apply "make_full_url" to get full url pages
log_data['Referer_Page'] = log_data['Referer_Page'].apply(make_full_url)

# %%
# Referer Pages by counts
referer_pages = pd.DataFrame(log_data['Referer_Page'].value_counts())

# Setting an index
referer_pages.reset_index(inplace=True)

# Changing column names
referer_pages.columns = ['Referer_Pages', 'Count']

# %%
referer_pages.head(10)
# Out:
#                                        Referer_Pages  Count
# 0       http://www.almhuette-raith.at/administrator/  53668
# 1                     http://www.almhuette-raith.at/   2170
# 2  http://www.almhuette-raith.at/administrator/in...   1630
# 3         http://www.almhuette-raith.at/wp-login.php    393
# 4  http://www.almhuette-raith.at/index.php?option...    328
# 5  https://search.yahoo.com/search=almhuette-rait...    243
# 6  https://www.bing.com/search?q=raith%20h%C3%BCt...     73
# 7                                 almhuette-raith.at     51
# 8                             https://www.google.at/     51
# 9  http://www.top1-seo-service.com/try.php?u=http...     41

# %% [markdown]
# *Referer Websites*

# %%
def get_website(url):
  """
  url: Url representing a referer page
  Example:
    url: 'http://www.google.com/images'
    return: 'http://www.google.com'
  """

  if url is not None:
    url = url.strip('http://')
    strip_index = url.find('/')
    stripped_url = url[:strip_index + 1]
    return 'http://' + stripped_url
  else:
    pass

print(get_website("http://www.almhuette-raith.at/wp-login.php"))
# Out:
# http://www.almhuette-raith.at/

# %%
# Home Page of Referer Page
log_data['Referer_Home_Page'] = log_data['Referer_Page'].apply(get_website)

# %%
# Most Frequent Referer Homes Pages
referer_websites = pd.DataFrame(log_data['Referer_Home_Page'].value_counts())

# Setting an index
referer_websites.reset_index(inplace=True)

# Changing column names
referer_websites.columns = ['Referer_Websites', 'Count']

# %%
referer_websites.head(20)
# Out:
#                          Referer_Websites  Count
# 0          http://www.almhuette-raith.at/  56450
# 1                                 http://   2676
# 2                              http://s:/    548
# 3        http://www.top1-seo-service.com/     41
# 4        http://www.booking.almenland.at/     40
# 5             http://www.v2.subscene.com/     21
# 6       http://www.whois.domaintools.com/      8
# 7             http://www.gazoblok.net.ua/      8
# 8              http://www.hyipmanager.in/      5
# 9          http://www.r.search.yahoo.com/      5
# 10  http://www.booking.oststeiermark.com/      5
# 11                  http://www.vucms.com/      5
# 12                  http://www.imgur.com/      4
# 13          http://www.web4.deskline.net/      4
# 14                  http://www.yandex.ru/      3
# 15              http://www.vpnhowto.info/      3
# 16     http://www.searchguide.level3.com/      3
# 17                    http://www.sivs.ru/      2
# 18             http://almhuette-raith.at/      1
# 19                      http://www.ya.ru/      1

# %%
log_data.tail(50)
# Out:
#        Client_IP_Address  ...                Referer_Home_Page
# 191641     213.150.1.137  ...                             None
# 191642     213.150.1.137  ...                             None
# 191643     213.150.1.137  ...                             None
# 191644     213.150.1.137  ...                             None
# 191645     213.150.1.137  ...                             None
# 191646     213.150.1.137  ...                             None
# 191647     213.150.1.137  ...                             None
# 191648     213.150.1.137  ...                             None
# 191649     213.150.1.137  ...                             None
# 191650     213.150.1.137  ...                             None
# 191651     213.150.1.137  ...                             None
# 191652     213.150.1.137  ...                             None
# 191653     213.150.1.137  ...                             None
# 191654     213.150.1.137  ...                             None
# 191655     213.150.1.137  ...                             None
# 191656     213.150.1.137  ...                             None
# 191657     213.150.1.137  ...                             None
# 191658     213.150.1.137  ...                             None
# 191659     213.150.1.137  ...                             None
# 191660     213.150.1.137  ...                             None
# 191665     5.196.210.211  ...                             None
# 191666     5.196.210.211  ...                             None
# 191667     5.196.210.211  ...    http://www.almhuette-raith.at
# 191670   107.152.242.125  ...                             None
# 191671      31.14.251.75  ...                             None
# 191672      31.14.251.75  ...                             None
# 191673   104.143.218.202  ...                             None
# 191674      5.189.130.68  ...                             None
# 191675      5.189.130.68  ...                             None
# 191676      5.189.130.68  ...    http://www.almhuette-raith.at
# 191677      5.189.130.68  ...                             None
# 191678      5.189.130.68  ...                             None
# 191681    51.254.119.191  ...                             None
# 191682    51.254.119.191  ...                             None
# 191683     167.60.48.205  ...                        http://s:
# 191684    172.102.203.83  ...                             None
# 191685    172.102.203.83  ...                             None
# 191686     94.242.246.24  ...      http://www.almhuette-raith.
# 191687    176.10.104.240  ...      http://www.almhuette-raith.
# 191688    185.100.85.191  ...      http://www.almhuette-raith.
# 191689    180.180.105.60  ...                             None
# 191690    180.180.105.60  ...                             None
# 191691    180.180.105.60  ...    http://www.almhuette-raith.at
# 191692    180.180.105.60  ...                             None
# 191693    180.180.105.60  ...                             None
# 191700    178.137.90.202  ...  http://www.prombudpostach.com.u
# 191703    134.249.55.100  ...     http://www.allsilver925.co.i
# 191704    134.249.55.100  ...     http://www.allsilver925.co.i
# 191705    134.249.55.100  ...     http://www.allsilver925.co.i
# 191708    134.249.55.100  ...         http://www.vipsiterip.or
#
# [50 rows x 8 columns]
